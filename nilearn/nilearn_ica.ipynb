# %%
import os
import numpy as np
from nilearn import image 
from nilearn import plotting 
from nilearn import decomposition
from nilearn.regions import RegionExtractor
from nilearn.connectome import ConnectivityMeasure

# %%
path_base = '/home/lussier/Projects/data/abide/'
path_func = 'func/'
path_conf = 'func/'

# %%
# A text file in the functional folder containing the names of the functional files in a single column is used to generate the list for the dypac model.
func = []
func_file = open((os.path.join(path_base,path_func, 'functional_batch.txt')),'r')
for line in func_file:
    func.append(os.path.join(path_base,path_func, (line.strip())))
func_file.close()
print (func)
# Out:
# ['/home/lussier/Projects/data/abide/func/fmri_sub0050004_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050006_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050007_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050008_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050009_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050010_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050012_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050013_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050014_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050015_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050016_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050019_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050020_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050022_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050023_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050024_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050025_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050026_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050027_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050028_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050029_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050031_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050032_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050033_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050034_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050036_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050037_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050038_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050039_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050040_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050041_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050042_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050043_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050044_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050045_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050046_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050047_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050048_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050049_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050051_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050052_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050053_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050054_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050056_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050057_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050059_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050060_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050102_session1_run1_n.nii.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050103_session1_run1_n.nii.gz', '/home/lussier/Projects/data/a ...

# %%
# A similar text file with the names of the confounds files in the same order as the functional is used to create the confounds file list for the model.
conf = []
conf_file = open((os.path.join(path_base,path_conf, 'confounds_batch.txt')),'r')
for line in conf_file:
    conf.append(os.path.join(path_base,path_conf, (line.strip())))
conf_file.close()
print (conf)
# Out:
# ['/home/lussier/Projects/data/abide/func/fmri_sub0050004_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050006_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050007_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050008_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050009_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050010_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050012_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050013_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050014_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050015_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050016_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050019_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050020_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050022_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050023_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050024_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050025_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050026_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050027_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050028_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050029_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050031_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050032_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050033_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050034_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050036_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050037_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050038_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050039_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050040_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050041_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050042_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050043_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050044_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050045_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050046_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050047_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050048_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050049_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050051_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050052_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050053_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050054_session1_run1_n_confounds.tsv.gz', '/home/lussier/Projects/data/abide/func/fmri_sub0050056_session1_run1_n_confounds.tsv. ...

# %%
#canica decomposition for sample
canica = decomposition.CanICA(n_components=50, smoothing_fwhm=6.,
                memory="nilearn_cache", memory_level=2,
                threshold=3., verbose=10, random_state=0,
                standardize=True, detrend=True,
                mask_strategy='template')
canica.fit(func, confounds=conf)
# Out:
# [MultiNiftiMasker.fit] Loading data from [/home/lussier/Projects/data/abide/func/fmri_sub0050004_session1_run1_n.nii.gz, /home/lussier/Projects/data/abide/func/fmri_sub0050006_session1_run1_n.nii.gz, /home/lussier/Projects/data/abide/func/fm
# [MultiNiftiMasker.fit] Computing mask
# Template mask computation
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050004_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050006_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050007_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050008_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050009_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050010_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050012_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050013_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050014_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050015_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050016_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050019_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050020_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050022_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050023_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050024_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050025_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050026_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050027_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050028_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050029_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050031_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050032_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050033_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050034_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050036_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050037_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050038_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050039_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050040_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050041_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050042_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050043_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050044_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050045_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050046_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050047_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050048_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050049_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050051_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050052_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050053_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050054_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050056_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050057_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050059_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050060_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050102_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050103_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050104_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050105_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050106_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050108_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050109_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050112_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050113_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050114_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050116_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050117_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050118_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050119_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050121_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050122_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050123_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050124_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050125_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050126_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050127_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050128_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050129_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050130_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050131_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050132_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050135_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050137_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050142_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050142_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050142_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050143_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050143_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050143_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050144_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050144_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050144_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050145_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050145_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050145_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050146_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050146_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050146_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050147_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050147_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050147_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050149_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050149_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050150_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050150_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050152_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050152_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050152_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050153_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050153_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050153_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050156_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050156_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050156_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050157_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050157_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050157_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050158_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050158_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050159_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050159_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050159_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050160_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050160_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050160_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050161_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050161_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050161_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050162_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050162_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050162_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050163_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050163_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050164_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050164_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050165_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050165_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050165_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050166_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050166_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050166_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050167_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050167_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050167_session1_run3_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050168_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0050168_session1_run2_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# ...
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051465_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051473_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051480_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051481_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051482_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051484_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051487_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051489_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051491_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051493_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051556_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051559_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051561_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051562_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051563_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051564_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051565_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051567_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051568_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051569_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051570_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051573_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051577_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051579_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051580_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051582_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051583_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051585_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051606_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/lussier/Projects/data/abide/func/fmri_sub0051607_session1_run1_n.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.005109, ..., -0.00351 ],
#        ...,
#        [-0.003242, ...,  0.001957]]), n_components=50, transpose=True, random_state=0, n_iter=3)
# /home/lussier/.local/lib/python3.6/site-packages/nilearn/decomposition/multi_pca.py:175: UserWarning: Persisting input arguments took 26.60s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=self.random_state, n_iter=3)
# __________________________________________________randomized_svd - 55.0s, 0.9min
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=209652396)
# __________________________________________________________fastica - 7.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=398764591)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.3s remaining:    0.0s
# __________________________________________________________fastica - 6.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=924231285)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   14.4s remaining:    0.0s
# _________________________________________________________fastica - 10.7s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=1478610112)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   25.2s remaining:    0.0s
# __________________________________________________________fastica - 7.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=441365315)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   32.4s remaining:    0.0s
# __________________________________________________________fastica - 7.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=1537364731)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   39.4s remaining:    0.0s
# _________________________________________________________fastica - 10.3s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=192771779)
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   49.8s remaining:    0.0s
# _________________________________________________________fastica - 17.0s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=1491434855)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.1min remaining:    0.0s
# _________________________________________________________fastica - 12.8s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=1819583497)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.3min remaining:    0.0s
# _________________________________________________________fastica - 12.6s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002773, ..., 0.000437],
#        ...,
#        [0.002459, ..., 0.000483]]), whiten=True, fun='cube', random_state=530702035)
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.5min remaining:    0.0s
# __________________________________________________________fastica - 9.1s, 0.2min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.7min finished
# CanICA(mask_strategy='template', memory=Memory(location=nilearn_cache/joblib),
#        memory_level=2, n_components=50, random_state=0, smoothing_fwhm=6.0,
#        threshold=3.0, verbose=10)

# %%
#retrieve components and project back into 3D space then save as nifti
components = canica.components_
components_img = canica.masker_.inverse_transform(components)
components_img.to_filename('canica_50.nii.gz')

# %%
#visualize components on map
plotting.plot_prob_atlas(components_img, view_type='filled_contours',
                         title='CanICA components')
# Out:
# /home/lussier/.local/lib/python3.6/site-packages/numpy/ma/core.py:2795: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)
# /home/lussier/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:99: UserWarning: No contour levels were found within the data range.
#   **kwargs)
# /home/lussier/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:99: UserWarning: linewidths is ignored by contourf
#   **kwargs)

# %%
#plot generated atlas for individual components
for i, cur_img in enumerate(image.iter_img(components_img)):
    plotting.plot_stat_map(cur_img, title="IC %d" % i, colorbar=False)
# Out:
# /home/lussier/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:602: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   facecolor=facecolor)
